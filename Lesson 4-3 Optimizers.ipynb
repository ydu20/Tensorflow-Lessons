# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#load dataset
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)

#define batch size
batch_size = 100
#calculate number of batches
n_batch = mnist.train.num_examples // batch_size

#define placeholders
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])

#create simple NeuroNet
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#quadratic cost function
loss = tf.reduce_mean(tf.square(y-prediction))
# loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))

#train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
train_step = tf.train.AdadeltaOptimizer(0.3).minimize(loss)

#initialize variables
init = tf.global_variables_initializer()

#find accuracy of trained model
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))   #convert a list of booleans into a single boolean depicting accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter" + str(epoch) + ", Testing Accuracy: " + str(acc))

# %%
Adam Optimizer @ 0.01:
Iter0, Testing Accuracy: 0.9249
Iter1, Testing Accuracy: 0.9283
Iter2, Testing Accuracy: 0.9291
Iter3, Testing Accuracy: 0.9254
Iter4, Testing Accuracy: 0.9287
Iter5, Testing Accuracy: 0.9245
Iter6, Testing Accuracy: 0.9263
Iter7, Testing Accuracy: 0.9289
Iter8, Testing Accuracy: 0.9291
Iter9, Testing Accuracy: 0.9323
Iter10, Testing Accuracy: 0.9275
Iter11, Testing Accuracy: 0.9278
Iter12, Testing Accuracy: 0.93
Iter13, Testing Accuracy: 0.9291
Iter14, Testing Accuracy: 0.9287
Iter15, Testing Accuracy: 0.9298
Iter16, Testing Accuracy: 0.9283
Iter17, Testing Accuracy: 0.9271
Iter18, Testing Accuracy: 0.9283
Iter19, Testing Accuracy: 0.9309
Iter20, Testing Accuracy: 0.9312

# %%
Momentum @ 0.1 and 0.9:
Iter0, Testing Accuracy: 0.8943
Iter1, Testing Accuracy: 0.9037
Iter2, Testing Accuracy: 0.9081
Iter3, Testing Accuracy: 0.9133
Iter4, Testing Accuracy: 0.9147
Iter5, Testing Accuracy: 0.9166
Iter6, Testing Accuracy: 0.9191
Iter7, Testing Accuracy: 0.92
Iter8, Testing Accuracy: 0.9203
Iter9, Testing Accuracy: 0.9204
Iter10, Testing Accuracy: 0.9222
Iter11, Testing Accuracy: 0.9226
Iter12, Testing Accuracy: 0.9227
Iter13, Testing Accuracy: 0.9231
Iter14, Testing Accuracy: 0.9247
Iter15, Testing Accuracy: 0.9255
Iter16, Testing Accuracy: 0.9254
Iter17, Testing Accuracy: 0.9249
Iter18, Testing Accuracy: 0.9249
Iter19, Testing Accuracy: 0.9267
Iter20, Testing Accuracy: 0.9274

# %%
Adadelta @ 0.3:
Iter0, Testing Accuracy: 0.8249
Iter1, Testing Accuracy: 0.8646
Iter2, Testing Accuracy: 0.8795
Iter3, Testing Accuracy: 0.8873
Iter4, Testing Accuracy: 0.8927
Iter5, Testing Accuracy: 0.8973
Iter6, Testing Accuracy: 0.8995
Iter7, Testing Accuracy: 0.9015
Iter8, Testing Accuracy: 0.9036
Iter9, Testing Accuracy: 0.9063
Iter10, Testing Accuracy: 0.9072
Iter11, Testing Accuracy: 0.9085
Iter12, Testing Accuracy: 0.9095
Iter13, Testing Accuracy: 0.9109
Iter14, Testing Accuracy: 0.9127
Iter15, Testing Accuracy: 0.9121
Iter16, Testing Accuracy: 0.913
Iter17, Testing Accuracy: 0.9141
Iter18, Testing Accuracy: 0.9145
Iter19, Testing Accuracy: 0.9139
Iter20, Testing Accuracy: 0.9154
