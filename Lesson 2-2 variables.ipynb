# %%
import tensorflow as tf

# %%
x = tf.Variable([1,2])
a = tf.constant([3,3])
#insert a subtraction op
sub = tf.subtract(x,a)
#insert an addition op
add = tf.add(x,sub)

init = tf.global_variables_initializer()  #important for variables!

with tf.Session() as sess:
    sess.run(init)
    print(sess.run(sub))
    print(sess.run(add))
# Out:
# [-2 -1]
# [-1  1]

# %%
#create a variable with initial value of 0
state = tf.Variable(0,name='counter')
#create a op that adds 1 to state
new_value = tf.add(state,1)
#assign value of new_value to state
update = tf.assign(state,new_value)
#variable initializer
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    print(sess.run(state))
    for x in range(5):
        sess.run(update)
        print(sess.run(state))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
